# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi2928/Data/blob/main/DS7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading data from different source files (csv,excel)

# %%
import pandas as pd
data=pd.read_csv("/content/sakshi.csv")

# %%
data
# Out:
#     SR NO     NAME   DEPT  SALARY
# 0       1   SAKSHI   ACCT   50000
# 1       2  PRITHVI   ACCT   50000
# 2       3   SANIYA     HR   50000
# 3       4   RUTUJA     HR   45000
# 4       5  BHUMIKA  SALES   40000
# 5       6     ISHA  SALES   45000
# 6       7  VAIBHAV     IT   30000
# 7       8  SIDDESH     IT   45000
# 8       9   RUSHAB  SALES   30000
# 9      10    SHAMS   ACCT   40000
# 10     11    DEEPA  SALES   35000
# 11     12   VAMSHI     IT   50000
# 12     13  TANISHA  SALES   30000
# 13     14    SHIVA     IT   34000

# %%
data1=pd.read_excel("/content/sakshi1.xlsx")
data1
# Out:
#     SR NO     NAME   DEPT  SALARY
# 0       1   SAKSHI   ACCT   50000
# 1       2  PRITHVI   ACCT   50000
# 2       3   SANIYA     HR   50000
# 3       4   RUTUJA     HR   45000
# 4       5  BHUMIKA  SALES   40000
# 5       6     ISHA  SALES   45000
# 6       7  VAIBHAV     IT   30000
# 7       8  SIDDESH     IT   45000
# 8       9   RUSHAB  SALES   30000
# 9      10    SHAMS   ACCT   40000
# 10     11    DEEPA  SALES   35000
# 11     12   VAMSHI     IT   50000
# 12     13  TANISHA  SALES   30000
# 13     14    SHIVA     IT   34000

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread("/content/northern lights.jpg")
plt.imshow(img)

# %% [markdown]
# # Summarizing the data

# %%
import seaborn as sns
import pandas as pd
data=pd.DataFrame({'Roll no':[1,2,3,4,5],'Name':['sakshi','saniya','prithvi','rutuja','bhumika'],'Marks':[56,57,58,59,54],'Class':['A','B','A','B','A']})

# %%
print(data)
# Out:
#    Roll no     Name  Marks Class
# 0        1   sakshi     56     A
# 1        2   saniya     57     B
# 2        3  prithvi     58     A
# 3        4   rutuja     59     B
# 4        5  bhumika     54     A

# %%
data.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# Class      0
# dtype: int64

# %%
data.describe()
# Out:
#         Roll no      Marks
# count  5.000000   5.000000
# mean   3.000000  56.800000
# std    1.581139   1.923538
# min    1.000000  54.000000
# 25%    2.000000  56.000000
# 50%    3.000000  57.000000
# 75%    4.000000  58.000000
# max    5.000000  59.000000

# %%
data.describe(include='object')
# Out:
#           Name Class
# count        5     5
# unique       5     2
# top     sakshi     A
# freq         1     3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
#  3   Class    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
data.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# Class      2
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
data['Name'].value_counts()
# Out:
# sakshi     1
# saniya     1
# prithvi    1
# rutuja     1
# bhumika    1
# Name: Name, dtype: int64

# %%
data.value_counts()
# Out:
# Roll no  Name     Marks  Class
# 1        sakshi   56     A        1
# 2        saniya   57     B        1
# 3        prithvi  58     A        1
# 4        rutuja   59     B        1
# 5        bhumika  54     A        1
# dtype: int64

# %%
data['Class'].duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Class, dtype: bool

# %%
data['Class'].value_counts()
# Out:
# A    3
# B    2
# Name: Class, dtype: int64

# %%
data['Marks'].mean()
# Out:
# 56.8

# %%
data['Marks'].var()
# Out:
# 3.7

# %%
correlation=data.corr()
# Out:
# <ipython-input-20-7f2487af4b08>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=data.corr()

# %%
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='coolwarm')
# Out:
# <Axes: >
