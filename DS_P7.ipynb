# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi2928/Data/blob/main/DS_P7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading data from different sources files formats(csv,excel)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
data=pd.read_csv("/content/DATASET.csv")
data
# Out:
#     ROLL NO       NAME
# 0         1     SAKSHI
# 1         2     SANIYA
# 2         3    PRITHVI
# 3         4    BHUMIKA
# 4         5     VAMSHI
# 5         6     RUTUJA
# 6         7       ISHA
# 7         8    VAIBHAV
# 8         9      VIVEK
# 9        10    SHUBHAM
# 10       11  HARSHITHA
# 11       12     SHWETA
# 12       13     RUSHAB
# 13       14      SHAMS
# 14       15    SIDDESH

# %%
d=pd.read_excel("/content/DATASET1.xlsx")
d
# Out:
#     ROLL NO       NAME
# 0         1     SAKSHI
# 1         2     SANIYA
# 2         3    PRITHVI
# 3         4    BHUMIKA
# 4         5     VAMSHI
# 5         6     RUTUJA
# 6         7       ISHA
# 7         8    VAIBHAV
# 8         9      VIVEK
# 9        10    SHUBHAM
# 10       11  HARSHITHA
# 11       12     SHWETA
# 12       13     RUSHAB
# 13       14      SHAMS
# 14       15    SIDDESH

# %%
img=mpimg.imread("/content/mountain-scene.jpg")
plt.imshow(img)

# %% [markdown]
# #SUMMARIZING DATA WITH STATISTICS

# %%
df=pd.DataFrame({"Rollno":[6192,6212,6212,6192,6201],"Name":["saniya","sakshi","prithvi","saniya","bhumika"],"Marks":[90,90,67,90,8],"Class":["A","A","B","B","B"]})
df
# Out:
#    Rollno     Name  Marks Class
# 0    6192   saniya     90     A
# 1    6212   sakshi     90     A
# 2    6212  prithvi     67     B
# 3    6192   saniya     90     B
# 4    6201  bhumika      8     B

# %%
df.isnull()
# Out:
#    Rollno   Name  Marks
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of    Rollno   Name  Marks
# 0   False  False  False
# 1   False  False  False
# 2   False  False  False
# 3   False  False  False
# 4   False  False  False>

# %%
df.describe()
# Out:
#             Rollno      Marks
# count     5.000000   5.000000
# mean   6201.200000  84.200000
# std      10.281051   9.833616
# min    6190.000000  67.000000
# 25%    6192.000000  85.000000
# 50%    6201.000000  89.000000
# 75%    6211.000000  90.000000
# max    6212.000000  90.000000

# %%
df.describe(include="object")
# Out:
#           Name
# count        5
# unique       5
# top     saniya
# freq         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rollno  5 non-null      int64
#  1   Name    5 non-null      object
#  2   Marks   5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.nunique()
# Out:
# Rollno    5
# Name      5
# Marks     5
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['Name'].duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Name, dtype: bool

# %%
df.nunique()
# Out:
# Rollno    3
# Name      4
# Marks     3
# dtype: int64

# %%
df.value_counts()
# Out:
# Rollno  Name     Marks
# 6192    saniya   90       2
# 6201    bhumika  8        1
# 6212    prithvi  67       1
#         sakshi   90       1
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# saniya     2
# sakshi     1
# prithvi    1
# bhumika    1
# Name: Name, dtype: int64

# %%
df.nunique()
# Out:
# Rollno    3
# Name      4
# Marks     3
# Class     2
# dtype: int64

# %%
df.value_counts()
# Out:
# Rollno  Name     Marks  Class
# 6192    saniya   90     A        1
#                         B        1
# 6201    bhumika  8      B        1
# 6212    prithvi  67     B        1
#         sakshi   90     A        1
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# B    3
# A    2
# Name: Class, dtype: int64

# %%
df['Marks'].mean()
# Out:
# 69.0

# %%
df['Marks'].var()
# Out:
# 1262.0

# %%
df.corr()
# Out:
# <ipython-input-39-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Rollno     Marks
# Rollno  1.000000 -0.118813
# Marks  -0.118813  1.000000

# %%
import seaborn as sns

# %%
cor=df.corr()
# Out:
# <ipython-input-42-48d031cc9737>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=df.corr()

# %%
sns.heatmap(cor,annot=True,fmt="2f",cmap="plasma")
# Out:
# <Axes: >
